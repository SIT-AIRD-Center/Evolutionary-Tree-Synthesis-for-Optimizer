# %%
from local.node import Node
from local.constnode import ConstNode
from local.varnode import VarNode
from local.funcnode import FuncNode
from local.func import *
from local.treeoptimizer import TreeOptimizer
from local.crossover import *
from local.Optimizer import *

import os
import json
import glob
import copy
import random
import pickle
import graphviz
import datetime
from PIL import Image
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, losses, metrics, optimizers

# %%
def create_folder():
    date = datetime.datetime.today()
    folder_path = str(date.year)
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)

    folder_path += "/"+str(date.month) +"_"+str(date.day)
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)

    folder_path += "/"+str(date.hour)+"_"+str(date.minute)
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)
        
    return folder_path


def Tounament_select(score_list, generation, Selection_size):
    candidate = random.sample(range(len(score_list)), Selection_size)
    candidate_score = [score_list[i] for i in candidate]
    index = candidate_score.index(max(candidate_score))
    return copy.deepcopy(generation[candidate[index]])

# %%
Population = 50
Max_generation = 500

Mutation_rate = 0.2
Crossover_rate = 0.8

Selection_size = 2

BATCH_SIZE = 512
EPOCHS = 10

loss_obj = metrics.Mean()
accuracy_obj = metrics.SparseCategoricalAccuracy()
val_loss_obj = metrics.SparseCategoricalCrossentropy()
val_accuracy_obj = metrics.SparseCategoricalAccuracy()

generation = []
generation += [Momentum() for _ in range(Population // 2)]
generation += [RMSProp() for _ in range(Population // 2)]

best_optim = SGD()
best_score = 0.0
best_score_list = []
past_progress = 0
folder_path = create_folder()
if not os.path.exists(folder_path+"/best_optim/"):
    os.mkdir(folder_path+"/best_optim/")
score_progress = []

# %%
def load_data():
    (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
    x_train, x_test = x_train[..., tf.newaxis] / 255.0, x_test[..., tf.newaxis] / 255.0

    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(BATCH_SIZE)
    test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH_SIZE)

    return train_dataset, test_dataset

def build_model():
    input = layers.Input(shape = (32, 32, 3))
    x = layers.Conv2D(32, 3, 2)(input)
    x = layers.LeakyReLU()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(units = 128, activation = "relu")(x)
    output = layers.Dense(units = 10, activation = "softmax")(x)

    return models.Model(input, output)

train_dataset, test_dataset = load_data()

model = build_model()
model.compile()
if not os.path.exists("models/"):
    os.mkdir("models/")
if not os.path.exists("models/model_cifar.keras"):
    model.save_weights("models/model_cifar.keras")

# %%
for progress in range(past_progress, Max_generation):
    fitness_list = []
    save_path = folder_path + f"/generation{progress}/"
    if not os.path.exists(save_path):
        os.mkdir(save_path)

    for index in tqdm(range(len(generation))):

        acc_list = []
        optimizer = generation[index]
        model.load_weights("models/model_cifar.keras")

        @tf.function
        def train_step(X, Y):
            with tf.GradientTape() as tape:
                pred = model(X)
                loss = losses.SparseCategoricalCrossentropy()(Y, pred)
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))
            
            loss_obj(loss)
            accuracy_obj(Y, pred)


        @tf.function
        def test_step(X, Y):
            pred = model(X)
            
            val_loss_obj(Y, pred)
            val_accuracy_obj(Y, pred)

        for i in range(EPOCHS):
            
            loss_obj.reset_state()
            accuracy_obj.reset_state()
            val_loss_obj.reset_state()
            val_accuracy_obj.reset_state()
            for X, Y in train_dataset:
                train_step(X, Y)
            
            for X, Y in test_dataset:
                test_step(X, Y)
        
            acc_list.append(val_accuracy_obj.result().numpy())
        fitness_list.append(max(acc_list))
        optimizer.plot_struct(f"{save_path}/optimizer_{index}_{max(acc_list)}")
        pickle_file = open(f"{save_path}/optimizer_{index}_{max(acc_list)}.pickle", mode= "wb")
        pickle.dump(optimizer, pickle_file)
        pickle_file.close()


    for index in range(len(fitness_list)):
        if fitness_list[index] > best_score:
            best_score = fitness_list[index]
            best_optim = copy.deepcopy(generation[index])

            best_optim.plot_struct(f"{folder_path}/best_optim/generation_{progress}_{index}_{best_score}")
            pickle_file = open(f"{folder_path}/best_optim/generation_{progress}_{index}_{best_score}.pickle", mode= "wb")
            pickle.dump(best_optim, pickle_file)
            pickle_file.close()
    
    best_score_list.append(best_score)
    print(best_score)
    json_file = open(f"{folder_path}/best_optim/score{progress}.json", "w")
    json.dump(str(best_score), json_file)
    json_file.close()


    next_generation = []

    while len(next_generation) < Population:
        parent1 = Tounament_select(fitness_list, generation, Selection_size)
        parent2 = Tounament_select(fitness_list, generation, Selection_size)

        if random.random() < Crossover_rate:
            parent1, parent2 = crossover(parent1, parent2)
        
        next_generation.append(parent1)
        next_generation.append(parent2)
    
    for index, genetic in enumerate(next_generation):
        if random.random() < Mutation_rate:
            genetic.mutate()

    next_generation.append(copy.deepcopy(best_optim))
    next_generation.append(Momentum())
    next_generation.append(RMSProp())        
    
    generation = next_generation[len(next_generation) - Population:]

    # pickleファイルが思ったより容量大きかったので、現世代の評価と進化が終わったら、ひとつ前の世代のpickleファイルを削除
    check_path = folder_path + f"/generation{progress -1}"
    pickle_list = glob.glob(check_path +"/*.pickle")
    for path in pickle_list:
        os.remove(path)
# Out:
# 100%|██████████| 50/50 [12:19<00:00, 14.78s/it]
# 100%|██████████| 50/50 [11:30<00:00, 13.82s/it]
# 100%|██████████| 50/50 [10:37<00:00, 12.75s/it]
# 100%|██████████| 50/50 [10:49<00:00, 12.99s/it]
# 100%|██████████| 50/50 [11:10<00:00, 13.42s/it]
# 100%|██████████| 50/50 [11:04<00:00, 13.29s/it]
# 100%|██████████| 50/50 [11:13<00:00, 13.47s/it]
# 100%|██████████| 50/50 [11:04<00:00, 13.29s/it]
# 100%|██████████| 50/50 [10:42<00:00, 12.84s/it]
# 100%|██████████| 50/50 [10:55<00:00, 13.12s/it]
# 100%|██████████| 50/50 [10:42<00:00, 12.85s/it]
# 100%|██████████| 50/50 [10:57<00:00, 13.14s/it]
# 100%|██████████| 50/50 [10:57<00:00, 13.15s/it]
# 100%|██████████| 50/50 [10:35<00:00, 12.70s/it]
# 100%|██████████| 50/50 [11:00<00:00, 13.21s/it]
# 100%|██████████| 50/50 [11:00<00:00, 13.22s/it]
# 100%|██████████| 50/50 [10:47<00:00, 12.96s/it]
# 100%|██████████| 50/50 [10:36<00:00, 12.73s/it]
# 100%|██████████| 50/50 [10:49<00:00, 12.99s/it]
# 100%|██████████| 50/50 [11:00<00:00, 13.21s/it]
# 100%|██████████| 50/50 [10:52<00:00, 13.05s/it]
# 100%|██████████| 50/50 [10:50<00:00, 13.01s/it]
# 100%|██████████| 50/50 [10:56<00:00, 13.13s/it]
# 100%|██████████| 50/50 [10:57<00:00, 13.15s/it]
# 100%|██████████| 50/50 [10:59<00:00, 13.20s/it]
# 100%|██████████| 50/50 [10:48<00:00, 12.98s/it]
# 100%|██████████| 50/50 [10:55<00:00, 13.11s/it]
# 100%|██████████| 50/50 [10:29<00:00, 12.59s/it]
# 100%|██████████| 50/50 [10:27<00:00, 12.55s/it]
# 100%|██████████| 50/50 [10:18<00:00, 12.38s/it]
# 100%|██████████| 50/50 [10:19<00:00, 12.40s/it]
# 100%|██████████| 50/50 [11:15<00:00, 13.51s/it]
# 100%|██████████| 50/50 [12:04<00:00, 14.49s/it]
# 100%|██████████| 50/50 [12:08<00:00, 14.58s/it]
# 100%|██████████| 50/50 [11:29<00:00, 13.79s/it]
# 100%|██████████| 50/50 [11:02<00:00, 13.26s/it]
# 100%|██████████| 50/50 [10:52<00:00, 13.05s/it]
# 100%|██████████| 50/50 [10:56<00:00, 13.13s/it]
# 100%|██████████| 50/50 [10:54<00:00, 13.08s/it]
# 100%|██████████| 50/50 [10:32<00:00, 12.66s/it]
# 100%|██████████| 50/50 [10:34<00:00, 12.70s/it]
# 100%|██████████| 50/50 [10:39<00:00, 12.79s/it]
# 100%|██████████| 50/50 [10:46<00:00, 12.93s/it]
# 100%|██████████| 50/50 [10:58<00:00, 13.17s/it]
# 100%|██████████| 50/50 [10:52<00:00, 13.06s/it]
# 100%|██████████| 50/50 [11:14<00:00, 13.48s/it]
# 100%|██████████| 50/50 [11:17<00:00, 13.56s/it]
# 100%|██████████| 50/50 [11:36<00:00, 13.93s/it]
# 100%|██████████| 50/50 [11:55<00:00, 14.32s/it]
# 100%|██████████| 50/50 [11:44<00:00, 14.09s/it]
# 100%|██████████| 50/50 [11:31<00:00, 13.84s/it]
# 100%|██████████| 50/50 [11:59<00:00, 14.39s/it]
# 100%|██████████| 50/50 [12:43<00:00, 15.28s/it]
# 100%|██████████| 50/50 [12:12<00:00, 14.66s/it]
# 100%|██████████| 50/50 [11:44<00:00, 14.09s/it]
# 100%|██████████| 50/50 [11:11<00:00, 13.42s/it]
# 100%|██████████| 50/50 [11:10<00:00, 13.41s/it]
# 100%|██████████| 50/50 [11:18<00:00, 13.56s/it]
# 100%|██████████| 50/50 [11:25<00:00, 13.71s/it]
# 100%|██████████| 50/50 [12:38<00:00, 15.17s/it]
# 100%|██████████| 50/50 [12:38<00:00, 15.17s/it]
# 100%|██████████| 50/50 [12:43<00:00, 15.26s/it]
# 100%|██████████| 50/50 [13:09<00:00, 15.80s/it]
# 100%|██████████| 50/50 [12:37<00:00, 15.15s/it]
# 100%|██████████| 50/50 [13:06<00:00, 15.74s/it]
# 100%|██████████| 50/50 [13:10<00:00, 15.81s/it]
# 100%|██████████| 50/50 [12:12<00:00, 14.65s/it]
# 100%|██████████| 50/50 [12:08<00:00, 14.57s/it]
# 100%|██████████| 50/50 [11:22<00:00, 13.64s/it]
# 100%|██████████| 50/50 [12:03<00:00, 14.46s/it]
# 100%|██████████| 50/50 [11:56<00:00, 14.32s/it]
# 100%|██████████| 50/50 [11:17<00:00, 13.55s/it]
# 100%|██████████| 50/50 [11:09<00:00, 13.39s/it]
# 100%|██████████| 50/50 [11:30<00:00, 13.80s/it]
# 100%|██████████| 50/50 [12:20<00:00, 14.82s/it]
# 100%|██████████| 50/50 [12:53<00:00, 15.46s/it]
# 100%|██████████| 50/50 [12:29<00:00, 14.98s/it]
# 100%|██████████| 50/50 [13:05<00:00, 15.72s/it]
# 100%|██████████| 50/50 [12:42<00:00, 15.26s/it]
# 100%|██████████| 50/50 [12:56<00:00, 15.53s/it]
# 100%|██████████| 50/50 [13:21<00:00, 16.03s/it]
# 100%|██████████| 50/50 [13:17<00:00, 15.96s/it]
# 100%|██████████| 50/50 [13:24<00:00, 16.09s/it]
# 100%|██████████| 50/50 [13:57<00:00, 16.75s/it]
# 100%|██████████| 50/50 [13:44<00:00, 16.48s/it]
# 100%|██████████| 50/50 [13:56<00:00, 16.73s/it]
# 100%|██████████| 50/50 [13:06<00:00, 15.73s/it]
# 100%|██████████| 50/50 [15:51<00:00, 19.03s/it]
# 100%|██████████| 50/50 [16:44<00:00, 20.09s/it]
# 100%|██████████| 50/50 [22:04<00:00, 26.48s/it]
# 100%|██████████| 50/50 [23:02<00:00, 27.65s/it]
#  70%|███████   | 35/50 [14:10<06:02, 24.17s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.873414 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.881212 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.883208 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886337 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.888765 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898317 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.904466 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.910878 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.917817 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.924864 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.932019 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.939286 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.946667 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.954166 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.961783 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.970242 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.977769 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.98577 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.993903 to fit
# 100%|██████████| 50/50 [22:31<00:00, 27.04s/it]
#   8%|▊         | 4/50 [01:44<17:36, 22.98s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.873414 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.881212 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.883208 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886337 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.888765 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898317 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.904466 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.910878 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.917817 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.924864 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.932019 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.939286 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.946667 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.954166 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.961783 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.970242 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.977769 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.98577 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.993903 to fit
# 100%|██████████| 50/50 [24:07<00:00, 28.96s/it]
#  12%|█▏        | 6/50 [02:30<16:17, 22.23s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.981019 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.990868 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.993391 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.997352 to fit
#  70%|███████   | 35/50 [17:55<05:19, 21.28s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.873414 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.881212 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.883208 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886337 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.888765 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898317 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.904466 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.910878 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.917817 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.924864 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.932019 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.939286 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.946667 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.954166 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.961783 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.970242 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.977769 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.98577 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.993903 to fit
# 100%|██████████| 50/50 [26:44<00:00, 32.09s/it]
# 100%|██████████| 50/50 [25:04<00:00, 30.08s/it]
# 100%|██████████| 50/50 [25:58<00:00, 31.16s/it]
#  78%|███████▊  | 39/50 [15:17<04:28, 24.42s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.900118 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.906593 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.913162 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.919827 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.926642 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.933533 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.942447 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.94473 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.948311 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.952142 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.95539 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.962575 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.966293 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.970012 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.97402 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.978178 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.989043 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995413 to fit
# 100%|██████████| 50/50 [21:52<00:00, 26.25s/it]
# 100%|██████████| 50/50 [19:26<00:00, 23.34s/it]
# 100%|██████████| 50/50 [20:22<00:00, 24.44s/it]
# 100%|██████████| 50/50 [27:30<00:00, 33.02s/it]
# 100%|██████████| 50/50 [21:13<00:00, 25.48s/it]
# 100%|██████████| 50/50 [26:41<00:00, 32.03s/it]
# 100%|██████████| 50/50 [29:39<00:00, 35.58s/it]
# 100%|██████████| 50/50 [29:19<00:00, 35.20s/it]
#   4%|▍         | 2/50 [00:56<24:26, 30.55s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.875257 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.881283 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.88749 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.893784 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.900168 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.906643 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.913213 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.919879 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.9268 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.933985 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.941283 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.948696 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.956226 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.963877 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971651 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.979523 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.985859 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.989013 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.994718 to fit
#  18%|█▊        | 9/50 [06:59<18:57, 27.75s/it]   dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.579608 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.582245 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.584947 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.587675 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.590428 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.593207 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.596013 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.598845 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.60177 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.604792 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.607843 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.610926 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.61404 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.617186 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.620364 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.623563 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.626125 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.627396 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.629687 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.632775 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.636092 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.641258 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.644538 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.647851 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.651095 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.653575 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.656719 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.660319 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.663958 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.667638 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.671359 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.675121 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.678926 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.682774 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.686666 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.690602 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.694584 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.698612 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.702672 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.705911 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.706627 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.710796 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.716783 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.721057 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.727687 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.731913 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.736188 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.739394 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.745297 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.748686 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.751951 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.753022 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.755575 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.76174 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.766551 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.773847 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.778628 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.783637 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.788066 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.79268 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.803723 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.811004 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.816501 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.822073 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.827721 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.833978 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.839534 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.845971 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.851688 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.857483 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.86363 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.869866 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.87925 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.885427 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.891692 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898046 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.902424 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.910043 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.915024 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.879179 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.899772 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.907422 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.905316 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.892834 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898415 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.905666 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.912526 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.918641 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.950264 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960853 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.967777 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.951616 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.963565 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.968521 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.994869 to fit
#  46%|████▌     | 23/50 [25:36<15:12, 33.80s/it]   dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.91334 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.919905 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.926669 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.933533 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.940499 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.947571 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.954749 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.962038 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.969639 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.977507 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.985503 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.993632 to fit
# 100%|██████████| 50/50 [46:31<00:00, 55.82s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.962179 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971507 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.974049 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.97774 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.980754 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.988446 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.99626 to fit
#  18%|█▊        | 9/50 [08:55<44:30, 65.13s/it]   dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.992639 to fit
#  46%|████▌     | 23/50 [23:26<22:52, 50.84s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.80564 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.810743 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.815993 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.82131 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.826698 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.832157 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.837688 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.843293 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.849128 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.855156 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.86127 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.867471 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.873763 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.880147 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886625 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.89315 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898415 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.901034 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.905791 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.912171 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.919105 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.929903 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.936816 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.943832 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.950733 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.956031 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.962066 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.967406 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.97486 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.978119 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.982106 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.990179 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.997686 to fit
# 100%|██████████| 50/50 [46:20<00:00, 55.60s/it]
#  30%|███       | 15/50 [11:31<26:43, 45.82s/it]  dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.889827 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.896057 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.900613 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.904217 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.907522 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.911968 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.922027 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.92848 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.935478 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.9428 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.950236 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.957791 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.965467 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.973268 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.981195 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.989252 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.998203 to fit
#  78%|███████▊  | 39/50 [32:00<10:01, 54.73s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.955836 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.965041 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.967549 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971162 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.974136 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.981724 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.989431 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.997291 to fit
#  92%|█████████▏| 46/50 [42:20<05:35, 83.94s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.962179 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971507 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.974049 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.97774 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.980754 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.988446 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.99626 to fit
# 100%|██████████| 50/50 [46:14<00:00, 55.48s/it]
#  20%|██        | 10/50 [13:59<1:01:30, 92.26s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.96855 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.978003 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.980578 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.984319 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.987374 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995171 to fit
#  44%|████▍     | 22/50 [25:13<14:18, 30.66s/it]   dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.727687 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.731847 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.736122 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.740447 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.744823 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.749251 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.753732 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.758267 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.762964 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.767827 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.772752 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.777741 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.782795 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.787914 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.793102 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.798338 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.802542 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.804631 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.808403 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.813501 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.818991 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.827575 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.833045 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.838588 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.844032 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.848205 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.852952 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.857147 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.862971 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.865524 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.868644 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.874953 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.880833 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.887273 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.893515 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.898218 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.904916 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.911765 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.918692 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.925752 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.932921 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.940203 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.948284 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.955473 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.963849 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971277 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.978821 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.986839 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.99499 to fit
#  50%|█████     | 25/50 [33:18<41:11, 98.84s/it] dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.717552 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.722727 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.724133 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.726155 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.727816 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.732044 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.736321 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.740665 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.745247 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.749886 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.754583 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.759339 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.764156 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.769034 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.773975 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.77898 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.78405 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.789186 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.797057 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.80213 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.807447 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.812895 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.818398 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.826948 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.83241 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.837945 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.842513 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.845469 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.851445 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.85699 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.86313 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.869036 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.873437 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.879816 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886241 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.890964 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.896179 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.902896 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.909866 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.920111 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.926878 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.933985 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.941283 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.948696 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.956226 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.963877 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971651 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.979552 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.987583 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.996533 to fit
# 100%|██████████| 50/50 [51:51<00:00, 62.22s/it]
#  80%|████████  | 40/50 [26:25<03:28, 20.88s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.69288 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.697705 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.699014 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.700913 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.702461 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.706398 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.71038 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.714423 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.718685 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.722998 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.727364 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.731782 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.736254 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.740782 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.745365 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.750006 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.754704 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.759462 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.766731 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.771424 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.776359 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.781395 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.786458 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.794371 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.79941 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.804513 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.808722 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.811446 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.816949 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.822052 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.8277 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.833109 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.837174 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.843033 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.848908 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.853241 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.858044 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.8642 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.87056 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.879958 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886145 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.892639 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.899303 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.906067 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.912933 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.919905 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.926983 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.934172 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.941472 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.949575 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.956785 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.965183 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.972632 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.980197 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.988238 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.996412 to fit
# 100%|██████████| 50/50 [36:52<00:00, 44.24s/it]
#  64%|██████▍   | 32/50 [21:46<15:30, 51.71s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.986453 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.994114 to fit
# 100%|██████████| 50/50 [31:43<00:00, 38.07s/it]
#   6%|▌         | 3/50 [00:45<12:08, 15.49s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.934385 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.94177 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.948531 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.951865 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.959109 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.966464 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.973817 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.980431 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.988476 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995625 to fit
#  70%|███████   | 35/50 [23:58<06:10, 24.68s/it] dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.687112 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.690821 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.694628 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.698478 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.702371 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.706307 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.710288 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.714314 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.718496 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.722807 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.72717 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.731586 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.736056 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.740581 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.745162 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.749765 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.753472 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.755313 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.758653 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.763124 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.767971 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.775495 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.780297 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.785158 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.789928 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.793582 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.797736 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.801404 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.806513 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.808742 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.811466 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.816969 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.822073 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.8277 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.833109 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.837196 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.843033 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.848974 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.854955 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.861066 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.867265 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.873554 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.879934 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.886409 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.89298 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.899649 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.906418 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.913289 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.920266 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.92735 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.934518 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.940284 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.94593 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.949548 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.957428 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.964757 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.972545 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.980461 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.987493 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995292 to fit
# 100%|██████████| 50/50 [36:04<00:00, 43.28s/it]
# 100%|██████████| 50/50 [25:43<00:00, 30.86s/it]
# 100%|██████████| 50/50 [19:01<00:00, 22.82s/it]
# 100%|██████████| 50/50 [17:18<00:00, 20.77s/it]
# 100%|██████████| 50/50 [18:24<00:00, 22.09s/it]
# 100%|██████████| 50/50 [15:52<00:00, 19.05s/it]
# 100%|██████████| 50/50 [21:58<00:00, 26.37s/it]
# 100%|██████████| 50/50 [15:23<00:00, 18.47s/it]
# 100%|██████████| 50/50 [15:02<00:00, 18.04s/it]
# 100%|██████████| 50/50 [13:20<00:00, 16.01s/it]
# 100%|██████████| 50/50 [13:44<00:00, 16.49s/it]
# 100%|██████████| 50/50 [14:34<00:00, 17.50s/it]
# 100%|██████████| 50/50 [13:23<00:00, 16.07s/it]
# 100%|██████████| 50/50 [12:26<00:00, 14.94s/it]
# 100%|██████████| 50/50 [12:21<00:00, 14.83s/it]
# 100%|██████████| 50/50 [12:12<00:00, 14.66s/it]
# 100%|██████████| 50/50 [14:31<00:00, 17.44s/it]
# 100%|██████████| 50/50 [12:58<00:00, 15.56s/it]
# 100%|██████████| 50/50 [13:22<00:00, 16.05s/it]
# 100%|██████████| 50/50 [13:12<00:00, 15.84s/it]
# 100%|██████████| 50/50 [13:01<00:00, 15.63s/it]
# 100%|██████████| 50/50 [12:34<00:00, 15.08s/it]
# 100%|██████████| 50/50 [11:43<00:00, 14.08s/it]
# 100%|██████████| 50/50 [11:18<00:00, 13.57s/it]
# 100%|██████████| 50/50 [10:58<00:00, 13.18s/it]
# 100%|██████████| 50/50 [10:59<00:00, 13.18s/it]
# 100%|██████████| 50/50 [10:34<00:00, 12.69s/it]
# 100%|██████████| 50/50 [10:27<00:00, 12.54s/it]
# 100%|██████████| 50/50 [10:42<00:00, 12.85s/it]
# ...
# 100%|██████████| 50/50 [15:07<00:00, 18.14s/it]
# 100%|██████████| 50/50 [13:22<00:00, 16.05s/it]
# 100%|██████████| 50/50 [13:40<00:00, 16.40s/it]
# 100%|██████████| 50/50 [13:50<00:00, 16.62s/it]
# 100%|██████████| 50/50 [13:29<00:00, 16.19s/it]
# 100%|██████████| 50/50 [13:24<00:00, 16.09s/it]
# 100%|██████████| 50/50 [13:03<00:00, 15.68s/it]
# 100%|██████████| 50/50 [14:21<00:00, 17.24s/it]
# 100%|██████████| 50/50 [14:03<00:00, 16.88s/it]
# 100%|██████████| 50/50 [15:25<00:00, 18.50s/it]
# 100%|██████████| 50/50 [15:15<00:00, 18.32s/it]
# 100%|██████████| 50/50 [15:37<00:00, 18.76s/it]
# 100%|██████████| 50/50 [14:03<00:00, 16.87s/it]
# 100%|██████████| 50/50 [15:07<00:00, 18.16s/it]
#  22%|██▏       | 11/50 [03:06<11:23, 17.53s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.922442 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.929244 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.936173 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.943071 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.949218 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.953416 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960684 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.968063 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.975905 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.983846 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995746 to fit
# 100%|██████████| 50/50 [17:47<00:00, 21.35s/it]
#  22%|██▏       | 11/50 [02:32<08:56, 13.75s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.946367 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.953527 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960796 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.968063 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.974541 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.978967 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.986631 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.994416 to fit
#  52%|█████▏    | 26/50 [09:57<06:45, 16.88s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.922442 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.929244 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.936173 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.943071 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.949218 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.953416 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960684 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.968063 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.975905 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.983846 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995746 to fit
#  68%|██████▊   | 34/50 [16:11<08:11, 30.72s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.918667 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.925412 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.932258 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.939098 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.945193 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.949355 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.956561 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.963877 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.971651 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.979523 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.991347 to fit
#  74%|███████▍  | 37/50 [20:41<11:34, 53.39s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.922442 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.929244 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.936173 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.943071 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.949218 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.953416 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960684 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.968063 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.975905 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.983846 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.995746 to fit
# 100%|██████████| 50/50 [27:32<00:00, 33.05s/it]
#  68%|██████▊   | 34/50 [09:06<04:30, 16.88s/it]dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.946367 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.953527 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960796 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.968063 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.974541 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.978967 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.986631 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.994416 to fit
# 100%|██████████| 50/50 [16:35<00:00, 19.91s/it]
# 100%|██████████| 50/50 [13:30<00:00, 16.22s/it]
# 100%|██████████| 50/50 [13:09<00:00, 15.78s/it]
# 100%|██████████| 50/50 [12:37<00:00, 15.15s/it]
# 100%|██████████| 50/50 [11:55<00:00, 14.31s/it]
# 100%|██████████| 50/50 [11:38<00:00, 13.96s/it]
# 100%|██████████| 50/50 [11:55<00:00, 14.31s/it]
# 100%|██████████| 50/50 [12:04<00:00, 14.48s/it]
# 100%|██████████| 50/50 [12:06<00:00, 14.54s/it]
# 100%|██████████| 50/50 [12:31<00:00, 15.03s/it]
# 100%|██████████| 50/50 [12:01<00:00, 14.44s/it]
# 100%|██████████| 50/50 [12:24<00:00, 14.89s/it]
# 100%|██████████| 50/50 [12:20<00:00, 14.82s/it]
# 100%|██████████| 50/50 [12:33<00:00, 15.07s/it]
# 100%|██████████| 50/50 [12:49<00:00, 15.39s/it]
# 100%|██████████| 50/50 [12:59<00:00, 15.60s/it]
# 100%|██████████| 50/50 [12:26<00:00, 14.93s/it]
# 100%|██████████| 50/50 [12:45<00:00, 15.31s/it]
# 100%|██████████| 50/50 [12:14<00:00, 14.70s/it]
# 100%|██████████| 50/50 [12:18<00:00, 14.77s/it]
# 100%|██████████| 50/50 [12:01<00:00, 14.44s/it]
# 100%|██████████| 50/50 [11:58<00:00, 14.37s/it]
# 100%|██████████| 50/50 [11:30<00:00, 13.82s/it]
# 100%|██████████| 50/50 [11:31<00:00, 13.82s/it]
# 100%|██████████| 50/50 [11:44<00:00, 14.08s/it]
# 100%|██████████| 50/50 [11:52<00:00, 14.25s/it]
# 100%|██████████| 50/50 [11:54<00:00, 14.30s/it]
# 100%|██████████| 50/50 [12:15<00:00, 14.70s/it]
# 100%|██████████| 50/50 [12:01<00:00, 14.44s/it]
# 100%|██████████| 50/50 [12:19<00:00, 14.78s/it]
# 100%|██████████| 50/50 [12:18<00:00, 14.76s/it]
# 100%|██████████| 50/50 [12:08<00:00, 14.58s/it]
# 100%|██████████| 50/50 [12:03<00:00, 14.47s/it]
# 100%|██████████| 50/50 [12:08<00:00, 14.57s/it]
# 100%|██████████| 50/50 [11:27<00:00, 13.74s/it]
# 100%|██████████| 50/50 [11:30<00:00, 13.80s/it]
# 100%|██████████| 50/50 [12:11<00:00, 14.63s/it]
# 100%|██████████| 50/50 [12:02<00:00, 14.45s/it]
# 100%|██████████| 50/50 [12:04<00:00, 14.49s/it]
# 100%|██████████| 50/50 [12:35<00:00, 15.12s/it]
# 100%|██████████| 50/50 [12:23<00:00, 14.87s/it]
# 100%|██████████| 50/50 [12:36<00:00, 15.14s/it]
# 100%|██████████| 50/50 [12:40<00:00, 15.21s/it]
# 100%|██████████| 50/50 [13:01<00:00, 15.64s/it]
# 100%|██████████| 50/50 [13:32<00:00, 16.24s/it]
# 100%|██████████| 50/50 [12:38<00:00, 15.17s/it]
# 100%|██████████| 50/50 [11:52<00:00, 14.24s/it]
# 100%|██████████| 50/50 [11:39<00:00, 13.99s/it]
# 100%|██████████| 50/50 [12:03<00:00, 14.47s/it]
# 100%|██████████| 50/50 [11:25<00:00, 13.72s/it]
# 100%|██████████| 50/50 [11:27<00:00, 13.75s/it]
# 100%|██████████| 50/50 [11:27<00:00, 13.76s/it]
# 100%|██████████| 50/50 [11:42<00:00, 14.06s/it]
# 100%|██████████| 50/50 [11:34<00:00, 13.89s/it]
# 100%|██████████| 50/50 [11:39<00:00, 14.00s/it]
# 100%|██████████| 50/50 [11:24<00:00, 13.69s/it]
# 100%|██████████| 50/50 [11:47<00:00, 14.15s/it]
# 100%|██████████| 50/50 [11:48<00:00, 14.17s/it]
# 100%|██████████| 50/50 [12:02<00:00, 14.44s/it]
# 100%|██████████| 50/50 [11:53<00:00, 14.28s/it]
# 100%|██████████| 50/50 [12:06<00:00, 14.53s/it]
# 100%|██████████| 50/50 [12:13<00:00, 14.67s/it]
# 100%|██████████| 50/50 [12:50<00:00, 15.41s/it]
# 100%|██████████| 50/50 [12:33<00:00, 15.07s/it]
# 100%|██████████| 50/50 [13:01<00:00, 15.62s/it]
# 100%|██████████| 50/50 [13:24<00:00, 16.08s/it]
# 100%|██████████| 50/50 [12:56<00:00, 15.53s/it]
# 100%|██████████| 50/50 [13:02<00:00, 15.66s/it]
# 100%|██████████| 50/50 [12:27<00:00, 14.95s/it]
# 100%|██████████| 50/50 [12:11<00:00, 14.63s/it]
# 100%|██████████| 50/50 [12:42<00:00, 15.25s/it]
# 100%|██████████| 50/50 [13:20<00:00, 16.00s/it]
# 100%|██████████| 50/50 [14:17<00:00, 17.15s/it]
# 100%|██████████| 50/50 [15:33<00:00, 18.67s/it]
# 100%|██████████| 50/50 [16:13<00:00, 19.46s/it]
# 100%|██████████| 50/50 [16:57<00:00, 20.34s/it]
# 100%|██████████| 50/50 [16:10<00:00, 19.41s/it]
# 100%|██████████| 50/50 [16:06<00:00, 19.33s/it]
# 100%|██████████| 50/50 [16:25<00:00, 19.71s/it]
# 100%|██████████| 50/50 [14:48<00:00, 17.76s/it]
# 100%|██████████| 50/50 [14:46<00:00, 17.73s/it]
# 100%|██████████| 50/50 [15:06<00:00, 18.13s/it]
# 100%|██████████| 50/50 [16:05<00:00, 19.30s/it]
# 100%|██████████| 50/50 [15:10<00:00, 18.21s/it]
# 100%|██████████| 50/50 [15:22<00:00, 18.45s/it]
# 100%|██████████| 50/50 [13:30<00:00, 16.21s/it]
# 100%|██████████| 50/50 [13:08<00:00, 15.76s/it]
# 100%|██████████| 50/50 [13:27<00:00, 16.15s/it]
# 100%|██████████| 50/50 [13:19<00:00, 15.98s/it]
# 100%|██████████| 50/50 [12:51<00:00, 15.42s/it]
# 100%|██████████| 50/50 [13:13<00:00, 15.88s/it]
# 100%|██████████| 50/50 [13:27<00:00, 16.14s/it]
# 100%|██████████| 50/50 [13:31<00:00, 16.23s/it]
# 100%|██████████| 50/50 [13:10<00:00, 15.80s/it]
# 100%|██████████| 50/50 [12:47<00:00, 15.35s/it]
# 100%|██████████| 50/50 [12:35<00:00, 15.11s/it]
# 100%|██████████| 50/50 [12:35<00:00, 15.11s/it]
# 100%|██████████| 50/50 [12:40<00:00, 15.21s/it]
# 100%|██████████| 50/50 [12:39<00:00, 15.18s/it]
# 100%|██████████| 50/50 [13:03<00:00, 15.68s/it]
# 100%|██████████| 50/50 [13:11<00:00, 15.84s/it]
# 100%|██████████| 50/50 [12:37<00:00, 15.14s/it]
# 100%|██████████| 50/50 [12:31<00:00, 15.04s/it]
# 100%|██████████| 50/50 [12:23<00:00, 14.87s/it]
# 100%|██████████| 50/50 [12:08<00:00, 14.57s/it]
# 100%|██████████| 50/50 [12:36<00:00, 15.13s/it]
# 100%|██████████| 50/50 [12:27<00:00, 14.96s/it]
# 100%|██████████| 50/50 [13:20<00:00, 16.02s/it]
# 100%|██████████| 50/50 [14:45<00:00, 17.72s/it]
# 100%|██████████| 50/50 [15:16<00:00, 18.33s/it]
# 100%|██████████| 50/50 [13:54<00:00, 16.70s/it]
# 100%|██████████| 50/50 [14:19<00:00, 17.18s/it]
# 100%|██████████| 50/50 [13:11<00:00, 15.83s/it]
# 100%|██████████| 50/50 [13:13<00:00, 15.87s/it]
# 100%|██████████| 50/50 [13:28<00:00, 16.16s/it]
# 100%|██████████| 50/50 [13:41<00:00, 16.42s/it]
# 100%|██████████| 50/50 [13:02<00:00, 15.66s/it]
# 100%|██████████| 50/50 [12:44<00:00, 15.29s/it]
# 100%|██████████| 50/50 [12:17<00:00, 14.75s/it]
# 100%|██████████| 50/50 [12:51<00:00, 15.42s/it]
# 100%|██████████| 50/50 [12:46<00:00, 15.32s/it]
# 100%|██████████| 50/50 [13:28<00:00, 16.17s/it]
# 100%|██████████| 50/50 [13:16<00:00, 15.94s/it]
# 100%|██████████| 50/50 [12:11<00:00, 14.64s/it]
# 100%|██████████| 50/50 [12:18<00:00, 14.77s/it]
# 100%|██████████| 50/50 [12:25<00:00, 14.90s/it]
# 100%|██████████| 50/50 [12:51<00:00, 15.42s/it]
# 100%|██████████| 50/50 [13:07<00:00, 15.76s/it]
# 100%|██████████| 50/50 [13:34<00:00, 16.29s/it]
# 100%|██████████| 50/50 [13:33<00:00, 16.27s/it]
# 100%|██████████| 50/50 [13:31<00:00, 16.22s/it]
# 100%|██████████| 50/50 [14:04<00:00, 16.88s/it]
# 100%|██████████| 50/50 [12:52<00:00, 15.46s/it]
# 100%|██████████| 50/50 [13:11<00:00, 15.83s/it]
# 100%|██████████| 50/50 [12:30<00:00, 15.02s/it]
# 100%|██████████| 50/50 [11:07<00:00, 13.35s/it]
# 100%|██████████| 50/50 [10:51<00:00, 13.03s/it]
# 100%|██████████| 50/50 [10:53<00:00, 13.07s/it]
# 100%|██████████| 50/50 [10:50<00:00, 13.01s/it]
# 100%|██████████| 50/50 [11:16<00:00, 13.52s/it]
# 100%|██████████| 50/50 [11:47<00:00, 14.14s/it]
# 100%|██████████| 50/50 [12:28<00:00, 14.97s/it]
# 100%|██████████| 50/50 [12:27<00:00, 14.94s/it]
# 100%|██████████| 50/50 [12:53<00:00, 15.48s/it]
# 100%|██████████| 50/50 [12:02<00:00, 14.45s/it]
# 100%|██████████| 50/50 [12:18<00:00, 14.77s/it]
# 100%|██████████| 50/50 [12:29<00:00, 14.98s/it]
# 100%|██████████| 50/50 [12:37<00:00, 15.15s/it]
# 100%|██████████| 50/50 [12:59<00:00, 15.60s/it]
# 100%|██████████| 50/50 [12:37<00:00, 15.15s/it]
# 100%|██████████| 50/50 [12:18<00:00, 14.77s/it]
# 100%|██████████| 50/50 [12:34<00:00, 15.09s/it]
# 100%|██████████| 50/50 [12:53<00:00, 15.47s/it]
# 100%|██████████| 50/50 [14:16<00:00, 17.12s/it]
# 100%|██████████| 50/50 [13:06<00:00, 15.73s/it]
# 100%|██████████| 50/50 [13:57<00:00, 16.74s/it]
# 100%|██████████| 50/50 [12:20<00:00, 14.82s/it]
# 100%|██████████| 50/50 [12:42<00:00, 15.25s/it]
# 100%|██████████| 50/50 [13:05<00:00, 15.72s/it]
# 100%|██████████| 50/50 [12:45<00:00, 15.32s/it]
# 100%|██████████| 50/50 [12:31<00:00, 15.02s/it]
# 100%|██████████| 50/50 [12:49<00:00, 15.39s/it]
# 100%|██████████| 50/50 [12:53<00:00, 15.46s/it]
# 100%|██████████| 50/50 [13:23<00:00, 16.06s/it]
# 100%|██████████| 50/50 [12:53<00:00, 15.47s/it]
# 100%|██████████| 50/50 [13:11<00:00, 15.84s/it]
# 100%|██████████| 50/50 [13:17<00:00, 15.95s/it]
# 100%|██████████| 50/50 [13:49<00:00, 16.58s/it]
# 100%|██████████| 50/50 [15:00<00:00, 18.00s/it]
# 100%|██████████| 50/50 [15:13<00:00, 18.27s/it]
# 100%|██████████| 50/50 [13:45<00:00, 16.52s/it]
# 100%|██████████| 50/50 [13:24<00:00, 16.08s/it]
# 100%|██████████| 50/50 [14:23<00:00, 17.26s/it]
# 100%|██████████| 50/50 [14:35<00:00, 17.51s/it]
# 100%|██████████| 50/50 [15:10<00:00, 18.21s/it]
# 100%|██████████| 50/50 [13:01<00:00, 15.63s/it]
# 100%|██████████| 50/50 [12:33<00:00, 15.06s/it]
# 100%|██████████| 50/50 [12:03<00:00, 14.48s/it]
# 100%|██████████| 50/50 [12:03<00:00, 14.47s/it]
# 100%|██████████| 50/50 [11:49<00:00, 14.19s/it]
# 100%|██████████| 50/50 [11:22<00:00, 13.65s/it]
# 100%|██████████| 50/50 [10:53<00:00, 13.07s/it]
# 100%|██████████| 50/50 [11:31<00:00, 13.82s/it]
# 100%|██████████| 50/50 [11:12<00:00, 13.44s/it]
# 100%|██████████| 50/50 [11:17<00:00, 13.56s/it]
# 100%|██████████| 50/50 [11:56<00:00, 14.34s/it]
# 100%|██████████| 50/50 [13:00<00:00, 15.60s/it]
# 100%|██████████| 50/50 [14:04<00:00, 16.90s/it]
# 100%|██████████| 50/50 [14:38<00:00, 17.57s/it]
# 100%|██████████| 50/50 [15:26<00:00, 18.53s/it]
# 100%|██████████| 50/50 [14:21<00:00, 17.24s/it]
# 100%|██████████| 50/50 [14:48<00:00, 17.78s/it]
# 100%|██████████| 50/50 [14:07<00:00, 16.95s/it]
# 100%|██████████| 50/50 [12:37<00:00, 15.15s/it]
# 100%|██████████| 50/50 [12:28<00:00, 14.97s/it]
# 100%|██████████| 50/50 [12:16<00:00, 14.72s/it]
# 100%|██████████| 50/50 [12:44<00:00, 15.29s/it]
# 100%|██████████| 50/50 [12:42<00:00, 15.26s/it]
# 100%|██████████| 50/50 [13:56<00:00, 16.72s/it]
# 100%|██████████| 50/50 [13:29<00:00, 16.19s/it]
# 100%|██████████| 50/50 [13:18<00:00, 15.97s/it]
# 100%|██████████| 50/50 [12:57<00:00, 15.54s/it]
# 100%|██████████| 50/50 [12:42<00:00, 15.26s/it]
# 100%|██████████| 50/50 [12:20<00:00, 14.81s/it]
# 100%|██████████| 50/50 [12:31<00:00, 15.04s/it]
# 100%|██████████| 50/50 [13:12<00:00, 15.85s/it]
# 100%|██████████| 50/50 [13:21<00:00, 16.04s/it]
# 100%|██████████| 50/50 [13:24<00:00, 16.09s/it]
# 100%|██████████| 50/50 [13:54<00:00, 16.68s/it]
# 100%|██████████| 50/50 [13:44<00:00, 16.50s/it]
# 100%|██████████| 50/50 [14:34<00:00, 17.49s/it]
#  38%|███▊      | 19/50 [05:17<07:48, 15.10s/it]

# %%
past_progress = 42

read_folder_path = folder_path +f"/{past_progress}"
pickle_list = glob.glob(read_folder_path +"/*.pickle")
tmp_generation = []
for path in pickle_list:
    genetic = pickle.load(path)
    tmp_generation.append(genetic)
